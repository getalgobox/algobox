# %%
import core
import pandas as pd
import numpy as np
import datetime as dt


dt_from = dt.datetime(year=2000, month=1, day=1)
dt_to = dt.datetime(year=2018, month=12, day=1)

data = core.ts_generator.CandleTimeSeriesGenerator(
    dt_from,
    dt_to,
    core.time.FTSE(),
    interval="1d",
    topic="IG:LLOY:1D"
)

bt = core.backtest.manager.BacktestManager(
    topic="IG:LLOY:1D",
    dt_from=dt_from,
    dt_to=dt_to,
    strat_id=1,
    lookback_period=30,
    data=data
)
bt.push_update = bt._dry_push_random_signal

# %%
i=0
for context, update in bt:
    i = i + 1
i
# Out:
# 4906

# %%
len(bt.observer.events)
print({e.type for e in bt.observer.events})
# Out:
# {'EQUITY_UPDATE', 'TRANSACTION_BUY', 'CASH_UPDATE', 'SIGNAL_SELL', 'SIGNAL_BUY', 'TRANSACTION_SELL', 'PRICE_UPDATE'}

# %%
equity, asset, cash, event = bt.observer._events_to_df()

# %%
print(len(equity))
print(len(asset))
print(len(cash))
print(len(event))
# Out:
# 4906
# 4906
# 4906
# 2890

# %%
merged = pd.concat([equity, asset, cash], axis=1)
merged = pd.merge(merged, event, how='left', left_index=True, right_index=True)
merged = merged.groupby(["datetime"], as_index=True)
print(len(merged))
merged.tail(100)
# Out:
# 4906
#                      asset    equity      cash SIGNAL_BUY SIGNAL_SELL  \
# datetime
# 2000-02-14 09:00:00  82.09  10000.00  10000.00        NaN         NaN
# 2000-02-15 09:00:00  82.08  10000.00  10000.00        NaN         NaN
# 2000-02-16 09:00:00  82.05  10000.00  10000.00        NaN         NaN
# 2000-02-17 09:00:00  82.06  10000.00  10000.00       True         NaN
# 2000-02-18 09:00:00  82.02   9995.16     70.74        NaN         NaN
# 2000-02-21 09:00:00  81.97   9989.11     70.74        NaN         NaN
# 2000-02-22 09:00:00  81.95   9986.69     70.74        NaN         NaN
# 2000-02-23 09:00:00  81.97   9989.11     70.74        NaN         NaN
# 2000-02-24 09:00:00  81.92   9983.06     70.74        NaN        True
# 2000-02-25 09:00:00  81.96   9983.06   9983.06        NaN         NaN
# 2000-02-28 09:00:00  82.02   9983.06   9983.06        NaN         NaN
# 2000-02-29 09:00:00  81.99   9983.06   9983.06        NaN         NaN
# 2000-03-01 09:00:00  81.96   9983.06   9983.06        NaN         NaN
# 2000-03-02 09:00:00  81.91   9983.06   9983.06        NaN         NaN
# 2000-03-03 09:00:00  81.91   9983.06   9983.06        NaN        True
# 2000-03-06 09:00:00  81.95   9983.06   9983.06        NaN         NaN
# 2000-03-07 09:00:00  81.94   9983.06   9983.06        NaN         NaN
# 2000-03-08 09:00:00  81.93   9983.06   9983.06        NaN         NaN
# 2000-03-09 09:00:00  81.87   9983.06   9983.06        NaN         NaN
# 2000-03-10 09:00:00  81.84   9983.06   9983.06        NaN         NaN
# 2000-03-13 09:00:00  81.83   9983.06   9983.06        NaN         NaN
# 2000-03-14 09:00:00  81.82   9983.06   9983.06        NaN         NaN
# 2000-02-17 09:00:00             NaN              NaN
# 2000-02-18 09:00:00            True              NaN
# 2000-02-21 09:00:00             NaN              NaN
# 2000-02-22 09:00:00             NaN              NaN
# 2000-02-23 09:00:00             NaN              NaN
# 2000-02-24 09:00:00             NaN              NaN
# 2000-02-25 09:00:00             NaN             True
# 2000-02-28 09:00:00             NaN              NaN
# 2000-02-29 09:00:00             NaN              NaN
# 2000-03-01 09:00:00             NaN              NaN
# 2000-03-02 09:00:00             NaN              NaN
# 2000-03-03 09:00:00             NaN              NaN
# 2000-03-06 09:00:00             NaN             True
# 2000-03-07 09:00:00             NaN              NaN
# 2000-03-08 09:00:00             NaN              NaN
# 2000-03-09 09:00:00             NaN              NaN
# 2000-03-10 09:00:00             NaN              NaN
# 2000-03-13 09:00:00             NaN              NaN
# 2000-03-14 09:00:00             NaN              NaN
# 2000-03-15 09:00:00             NaN              NaN
# 2000-03-16 09:00:00            True              NaN
# 2000-03-17 09:00:00             NaN              NaN
# 2000-03-20 09:00:00             NaN              NaN
# 2000-03-21 09:00:00             NaN              NaN
# 2000-03-22 09:00:00             NaN              NaN
# 2000-03-23 09:00:00             NaN             True
# 2000-03-24 09:00:00             NaN              NaN
# ...                             ...              ...
# 2018-10-26 09:00:00             NaN              NaN
# 2018-10-29 09:00:00             NaN              NaN
# 2018-10-30 09:00:00            True              NaN
# 2018-10-31 09:00:00             NaN              NaN
# 2018-11-01 09:00:00            True              NaN
# 2018-11-02 09:00:00             NaN              NaN
# 2018-11-05 09:00:00             NaN              NaN
# 2018-11-06 09:00:00             NaN              NaN
# 2018-11-07 09:00:00             NaN              NaN
# 2018-11-08 09:00:00             NaN              NaN
# 2018-11-09 09:00:00             NaN              NaN
# 2018-11-12 09:00:00             NaN              NaN
# 2018-11-13 09:00:00             NaN              NaN
# 2018-11-14 09:00:00            True              NaN
# 2018-11-14 09:00:00             NaN              NaN
# 2018-11-15 09:00:00             NaN             True
# 2018-11-15 09:00:00             NaN              NaN
# 2018-11-16 09:00:00             NaN             True
# 2018-11-19 09:00:00             NaN              NaN
# 2018-11-20 09:00:00             NaN             True
# 2018-11-20 09:00:00             NaN              NaN
# 2018-11-21 09:00:00            True              NaN
# 2018-11-22 09:00:00             NaN              NaN
# 2018-11-23 09:00:00             NaN              NaN
# 2018-11-26 09:00:00             NaN             True
# 2018-11-27 09:00:00             NaN              NaN
# 2018-11-28 09:00:00            True              NaN
# 2018-11-29 09:00:00             NaN              NaN
# 2018-11-30 09:00:00             NaN             True
# 2018-12-03 09:00:00             NaN              NaN
#
# [5327 rows x 7 columns]

# %%
# merged.plot()
# Out:
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730164.375, right=730164.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730165.375, right=730165.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730166.375, right=730166.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730167.375, right=730167.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730168.375, right=730168.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730171.375, right=730171.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730172.375, right=730172.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730173.375, right=730173.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730174.375, right=730174.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730175.375, right=730175.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730178.375, right=730178.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730179.375, right=730179.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730180.375, right=730180.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=
375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730368.375, right=730368.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730369.375, right=730369.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730370.375, right=730370.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730371.375, right=730371.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730374.375, right=730374.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730375.375, right=730375.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730376.375, right=730376.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730377.375, right=730377.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730378.375, right=730378.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730381.375, right=730381.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730382.375, right=730382.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730383.375, right=730383.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730384.375, right=730384.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730385.375, right=730385.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730388.375, right=730388.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730389.375, right=730389.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730390.375, right=730390.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730391.375, right=730391.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730392.375, right=730392.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730395.375, right=730395.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730396.375, right=730396.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730397.375, right=730397.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730398.375, right=730398.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730399.375, right=730399.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730402.375, right=730402.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730403.375, right=730403.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730404.375, right=730404.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730405.375, right=730405.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=730406.375, right=730406.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# ...
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=731777.375, right=731777.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=731778.375, right=731778.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=731781.375, right=731781.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=731782.375, right=731782.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=731783.375, right=731783.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=731784.375, right=731784.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=731785.375, right=731785.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=731788.375, right=731788.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=731789.375, right=731789.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=731790.375, right=731790.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=731791.375, right=731791.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=731792.375, right=731792.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=731795.375, right=731795.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=731796.375, right=731796.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=731797.375, right=731797.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=731798.375, right=731798.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=731799.375, right=731799.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=731802.375, right=731802.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=731803.375, right=731803.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=731804.375, right=731804.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=731805.375, right=731805.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=731806.375, right=731806.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=731809.375, right=731809.375
#   ax.set_xlim(left, right)
# /home/callam/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py:998: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=731810.375, right=731810.375
#   ax.set_xlim(left, right)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-8955a1fd4a87> in <module>
# ----> 1 merged.plot()
#
# ~/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in __call__(self, *args, **kwargs)
#     301             return self.plot(*args, **kwargs)
#     302         f.__name__ = 'plot'
# --> 303         return self._groupby.apply(f)
#     304
#     305     def __getattr__(self, name):
#
# ~/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     687         with option_context('mode.chained_assignment', None):
#     688             try:
# --> 689                 result = self._python_apply_general(f)
#     690             except Exception:
#     691
#
# ~/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     705     def _python_apply_general(self, f):
#     706         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 707                                                    self.axis)
#     708
#     709         return self._wrap_applied_output(
#
# ~/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     188             # group might be modified
#     189             group_axes = _get_axes(group)
# --> 190             res = f(group)
#     191             if not _is_indexed_like(res, group_axes):
#     192                 mutated = True
#
# ~/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in f(self)
#     299     def __call__(self, *args, **kwargs):
#     300         def f(self):
# --> 301             return self.plot(*args, **kwargs)
#     302         f.__name__ = 'plot'
#     303         return self._groupby.apply(f)
#
# ~/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2937                           fontsize=fontsize, colormap=colormap, table=table,
#    2938                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2939                           sort_columns=sort_columns, **kwds)
#    2940     __call__.__doc__ = plot_frame.__doc__
#    2941
#
# ~/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1968                  yerr=yerr, xerr=xerr,
#    1969                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1970                  **kwds)
#    1971
#    1972
#
# ~/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1796         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1797
# -> 1798     plot_obj.generate()
#    1799     plot_obj.draw()
#    1800     return plot_obj.result
#
# ~/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py in generate(self)
#     249         self._compute_plot_data()
#     250         self._setup_subplots()
# --> 251         self._make_plot()
#     252         self._add_table()
#     253         self._make_legend()
#
# ~/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py in _make_plot(self)
#     991                              stacking_id=stacking_id,
#     992                              is_errorbar=is_errorbar,
# --> 993                              **kwds)
#     994             self._add_legend_handle(newlines[0], label, index=i)
#     995
#
# ~/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py in _plot(cls, ax, x, y, style, column_num, stacking_id, **kwds)
#    1006             cls._initialize_stacker(ax, stacking_id, len(y))
#    1007         y_values = cls._get_stacked_values(ax, stacking_id, y, kwds['label'])
# -> 1008         lines = MPLPlot._plot(ax, x, y_values, style=style, **kwds)
#    1009         cls._update_stacker(ax, stacking_id, y)
#    1010         return lines
#
# ~/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_core.py in _plot(cls, ax, x, y, style, is_errorbar, **kwds)
#     596             else:
#     597                 args = (x, y)
# --> 598             return ax.plot(*args, **kwds)
#     599
#     600     def _get_index_name(self):
#
# ~/Documents/venvs/algobox/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/Documents/venvs/algobox/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1610
#    1611         for line in self._get_lines(*args, **kwargs):
# -> 1612             self.add_line(line)
#    1613             lines.append(line)
#    1614
#
# ~/Documents/venvs/algobox/lib/python3.6/site-packages/matplotlib/axes/_base.py in add_line(self, line)
#    1893             line.set_clip_path(self.patch)
#    1894
# -> 1895         self._update_line_limits(line)
#    1896         if not line.get_label():
#    1897             line.set_label('_line%d' % len(self.lines))
#
# ~/Documents/venvs/algobox/lib/python3.6/site-packages/matplotlib/axes/_base.py in _update_line_limits(self, line)
#    1915         Figures out the data limit of the given line, updating self.dataLim.
#    1916         """
# -> 1917         path = line.get_path()
#    1918         if path.vertices.size == 0:
#    1919             return
#
# ~/Documents/venvs/algobox/lib/python3.6/site-packages/matplotlib/lines.py in get_path(self)
#     943         """
#     944         if self._invalidy or self._invalidx:
# --> 945             self.recache()
#     946         return self._path
#     947
#
# ~/Documents/venvs/algobox/lib/python3.6/site-packages/matplotlib/lines.py in recache(self, always)
#     637     def recache(self, always=False):
#     638         if always or self._invalidx:
# --> 639             xconv = self.convert_xunits(self._xorig)
#     640             x = _to_unmasked_float_array(xconv).ravel()
#     641         else:
#
# ~/Documents/venvs/algobox/lib/python3.6/site-packages/matplotlib/artist.py in convert_xunits(self, x)
#     184         if ax is None or ax.xaxis is None:
#     185             return x
# --> 186         return ax.xaxis.convert_units(x)
#     187
#     188     def convert_yunits(self, y):
#
# ~/Documents/venvs/algobox/lib/python3.6/site-packages/matplotlib/axis.py in convert_units(self, x)
#    1528             return x
#    1529
# -> 1530         ret = self.converter.convert(x, self.units, self)
#    1531         return ret
#    1532
#
# ~/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_converter.py in convert(values, unit, axis)
#     293                       for v in values]
#     294         else:
# --> 295             values = DatetimeConverter._convert_1d(values, unit, axis)
#     296         return values
#     297
#
# ~/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/plotting/_converter.py in _convert_1d(values, unit, axis)
#     328
#     329             try:
# --> 330                 values = tools.to_datetime(values)
#     331                 if isinstance(values, Index):
#     332                     values = _dt_to_float_ordinal(values)
#
# ~/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     607             result = _convert_and_box_cache(arg, cache_array, box, errors)
#     608         else:
# --> 609             result = convert_listlike(arg, box, format)
#     610     else:
#     611         result = convert_listlike(np.array([arg]), box, format)[0]
#
# ~/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, box, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     300             arg, dayfirst=dayfirst, yearfirst=yearfirst,
#     301             utc=utc, errors=errors, require_iso8601=require_iso8601,
# --> 302             allow_object=True)
#     303
#     304     if tz_parsed is not None:
#
# ~/Documents/venvs/algobox/lib/python3.6/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1855             dayfirst=dayfirst,
#    1856             yearfirst=yearfirst,
# -> 1857             require_iso8601=require_iso8601
#    1858         )
#    1859     except ValueError as e:
#
# KeyboardInterrupt:
# ERROR:root:Invalid alias: The name clear can't be aliased because it is another magic command.
# ERROR:root:Invalid alias: The name more can't be aliased because it is another magic command.
# ERROR:root:Invalid alias: The name less can't be aliased because it is another magic command.
# ERROR:root:Invalid alias: The name man can't be aliased because it is another magic command.

# %%
merged.calc_stats()
merged.display()
merged["asset"].display_monthly_returns()
